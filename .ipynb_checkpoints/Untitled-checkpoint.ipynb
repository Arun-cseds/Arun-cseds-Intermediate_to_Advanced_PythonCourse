# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # User Input in Python

# %%
a = int(input("enter first no ="))
b= int(input("enter second no ="))
c=a+b
print("sum is = ", c)
# Out:
# enter first no = 23
# enter second no = 45
# sum is =  68
